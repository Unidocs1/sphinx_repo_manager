# %% [markdown]
# # Docker testing

# %%
# Build and mount
# !docker compose -f ./docker/docker-compose.yaml up --build docs-build
# Out:
# #0 building with "default" instance using docker driver
#
# #1 [docs-base internal] load build definition from Dockerfile
# #1 transferring dockerfile: 395B done
# #1 DONE 0.1s
#
# #2 [docs-base internal] load metadata for docker.io/library/python:3.10-bullseye
# #2 DONE 0.7s
#
# #3 [docs-base internal] load .dockerignore
# #3 transferring context: 2B done
# #3 DONE 0.1s
#
# #4 [docs-base 1/6] FROM docker.io/library/python:3.10-bullseye@sha256:a4d9982b391b91d6ffaae6156f2b55ed769d854682d6611c3805c436b1920b72
# #4 DONE 0.0s
#
# #5 [docs-base internal] load build context
# #5 transferring context: 38B done
# #5 DONE 0.1s
#
# #6 [docs-base 4/6] WORKDIR /app
# #6 CACHED
#
# #7 [docs-base 5/6] COPY requirements.txt requirements.txt
# #7 CACHED
#
# #8 [docs-base 2/6] RUN apt-get update && export DEBIAN_FRONTEND=noninteractive     && apt-get -y install --no-install-recommends make     && apt-get autoremove -y && apt-get clean -y && rm -rf /var/lib/apt/lists/*
# #8 CACHED
#
# ...
