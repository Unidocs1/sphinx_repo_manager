# %% [markdown]
# ## Initialize notebook environment

# %% [markdown]
# ### Initialize notebook imports and local variables

# %%
import os, shutil

# get the env variables
env = os.environ

# if project path is set, cwd to that path
if "PROJECT_PATH" in env:
    os.chdir(env["PROJECT_PATH"])

# get the project path
project_path = os.getcwd()
venv_path = os.path.join(project_path, "venv")
build_path = os.path.join(project_path, "build")
docs_path = os.path.join(project_path, "docs")
tools_path = os.path.join(project_path, "tools")

# cache project path back to env
os.environ["PROJECT_PATH"] = project_path

print("Environment variables: ", env)
print("Project path: ", project_path)
print("Venv path: ", venv_path)
print("Build path: ", build_path)
print("Docs path: ", docs_path)
print("Tools path: ", tools_path)
# Out:
# Environment variables:  environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'AMD_ENABLE_LLPC': '0', 'APPDATA': 'C:\\Users\\thoma\\AppData\\Roaming', 'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': '1', 'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey', 'CHOCOLATEYLASTPATHUPDATE': '133458471156510173', 'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_25344_EGRJIIAWURHFUDJS', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'AXR_THOMAS', 'COMSPEC': 'C:\\windows\\system32\\cmd.exe', 'CONDA_DEFAULT_ENV': 'py310', 'CONDA_EXE': 'C:\\Users\\thoma\\miniconda3\\Scripts\\conda.exe', 'CONDA_PREFIX': 'C:\\Users\\thoma\\miniconda3\\envs\\py310', 'CONDA_PROMPT_MODIFIER': '(py310) ', 'CONDA_PYTHON_EXE': 'C:\\Users\\thoma\\miniconda3\\python.exe', 'CONDA_ROOT': 'C:\\Users\\thoma\\miniconda3', 'CONDA_SHLVL': '1', 'CONFIGSETROOT': 'C:\\windows\\ConfigSetRoot', 'CUDA_INJECTION64_PATH': 'C:\\Program Files (x86)\\NVIDIA Corporation\\Nsight Visual Studio Edition 2023.3\\Monitor\\Common\\Injection64\\Nvda.Cuda.Injection.dll', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'EFC_17784': '1', 'ELECTRON_RUN_AS_NODE': '1', 'ERLANG_HOME': 'C:\\Program Files\\Erlang OTP', 'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer', 'FPS_BROWSER_USER_PROFILE_STRING': 'Default', 'GITLAB_ACCESS_TOKEN': 'TOKEN_GOES_HERE', 'GOPATH': 'C:\\Users\\thoma\\go', 'HOME': 'C:\\Users\\thoma', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\thoma', 'JETBRAINS RIDER': 'C:\\Program Files\\JetBrains\\JetBrains Rider 2023.3.3\\bin;', 'JPY_INTERRUPT_EVENT': '2380', 'LOCALAPPDATA': 'C:\\Users\\thoma\\AppData\\Local', 'LOGONSERVER': '\\\\AXR_THOMAS', 'NPM_TOKEN': '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', 'NUMBER_OF_PROCESSORS': '32', 'ONEDRIVE': 'C:\\Users\\thoma\\OneDrive', 'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined', 'OS': 'Windows_NT', 'PATH': 'c:\\Users\\thoma\\miniconda3\\envs\\py310;C:\\Users\\thoma\\miniconda3\\envs\\py310;C:\\Users\\thoma\\miniconda3\\envs\\py310\\Library\\mingw-w64\\bin;C:\\Users\\thoma\\miniconda3\\envs\\py310\\Library\\usr\\bin;C:\\Users\\thoma\\miniconda3\\envs\\py310\\Library\\bin;C:\\Users\\thoma\\miniconda3\\envs\\py310\\Scripts;C:\\Users\\thoma\\miniconda3\\envs\\py310\\bin;C:\\Users\\thoma\\miniconda3\\condabin;C:\\VulkanSDK\\1.3.275.0\\Bin;C:\\Program Files\\Eclipse Foundation\\jdk-8.0.302.8-hotspot\\bin;C:\\Program Files (x86)\\Common Files\\Oracle\\Java\\javapath;C:\\windows\\system32;C:\\windows;C:\\windows\\System32\\Wbem;C:\\windows\\System32\\WindowsPowerShell\\v1.0;C:\\windows\\System32\\OpenSSH;C:\\Program Files\\Microsoft VS Code\\bin;C:\\ProgramData\\chocolatey\\bin;C:\\Program Files\\nodejs;C:\\Program Files (x86)\\Windows Kits\\10\\Windows Performance Toolkit;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\Program Files\\dotnet;C:\\Program Files\\Perforce;C:\\Program Files\\Docker\\Docker\\resources\\bin;C:\\Program Files\\Go\\bin;C:\\Program Files\\Git\\cmd;C:\\Program Files\\PuTTY;C:\\Users\\thoma\\AppData\\Local\\Programs\\Python\\Python310\\Scripts;C:\\Users\\thoma\\AppData\\Local\\Programs\\Python\\Python310;C:\\Users\\thoma\\miniconda3;C:\\Users\\thoma\\miniconda3\\Library\\mingw-w64\\bin;C:\\Users\\thoma\\miniconda3\\Library\\usr\\bin;C:\\Users\\thoma\\miniconda3\\Library\\bin;C:\\Users\\thoma\\miniconda3\\Scripts;C:\\Users\\thoma\\AppData\\Local\\Programs\\Python\\Launcher;C:\\Users\\thoma\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\thoma\\AppData\\Roaming\\npm;C:\\Users\\thoma\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Users\\thoma\\.dotnet\\tools;C:\\Users\\thoma\\AppData\\Local\\Programs\\Python\\Python312;C:\\Program Files\\CMake\\bin;C:\\Users\\thoma\\.deno\\bin;C:\\Users\\thoma\\.dotnet\\tools;C:\\Users\\thoma\\AppData\\Local\\Programs\\Fiddler;C:\\Program Files\\JetBrains\\JetBrains Rider 2023.3.3\\bin;.;C:\\Users\\thoma\\AppData\\Local\\Y ...
# Project path:  d:\workspaces\multi_repo_docs\docs_update
# Venv path:  d:\workspaces\multi_repo_docs\docs_update\venv
# Build path:  d:\workspaces\multi_repo_docs\docs_update\build
# Docs path:  d:\workspaces\multi_repo_docs\docs_update\docs
# Tools path:  d:\workspaces\multi_repo_docs\docs_update\tools

# %% [markdown]
# ### Verify Versions

# %%
# !python --version
# !pip --version
# Out:
# Python 3.10.13
# pip 24.0 from c:\Users\thoma\miniconda3\envs\py310\lib\site-packages\pip (python 3.10)

# %% [markdown]
# ### Venv setup (if desired)

# %% [markdown]
# Run from a base python envirnoment as a kernel to create a venv. If using venv, make sure you change the kernel of the notebook to the venv after creation and re-run the imports and local variables section above before continuing.
#
# _Note: Skip if e.g. using conda or dev container._

# %%
# does venv exist?
if os.path.exists(venv_path):
    print("Venv exists at ", venv_path)
    print("Deleting old venv")
    shutil.rmtree(venv_path)

# %%
# create new venv
print("Creating root path ", venv_path)
os.makedirs(venv_path, exist_ok=True)
print("Creating new virtual environment ", venv_path)
# !python -m venv $venv_path
print("Venv created at ", venv_path)
# Out:
# Creating root path  d:\workspaces\multi_repo_docs\docs_update\venv
# Creating new virtual environment  d:\workspaces\multi_repo_docs\docs_update\venv
# Venv created at  d:\workspaces\multi_repo_docs\docs_update\venv

# %% [markdown]
# ### Install build requirements

# %%
# update pip
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (23.3.1)
# Collecting pip
#   Using cached pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.0-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.1
#     Uninstalling pip-23.3.1:
#       Successfully uninstalled pip-23.3.1
# Successfully installed pip-24.0

# %%
# import requirements
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: sphinx==7.3.7 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 6)) (7.3.7)
# Requirement already satisfied: sphinx_rtd_theme>=2.0.0 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: myst_parser>=0.18.0 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 8)) (3.0.1)
# Requirement already satisfied: sphinx_tabs>=3.4.5 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 9)) (3.4.5)
# Requirement already satisfied: sphinx_jinja2==0.0.1 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 10)) (0.0.1)
# Requirement already satisfied: PyYAML==6.0.1 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 13)) (6.0.1)
# Requirement already satisfied: colorama==0.4.6 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from -r requirements.txt (line 14)) (0.4.6)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (1.0.8)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (1.0.6)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (2.0.5)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (1.0.7)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: Pygments>=2.14 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (2.17.2)
# Requirement already satisfied: docutils<0.22,>=0.18.1 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (0.20.1)
# Requirement already satisfied: snowballstemmer>=2.0 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: babel>=2.9 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (2.15.0)
# Requirement already satisfied: alabaster~=0.7.14 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (1.4.1)
# Requirement already satisfied: requests>=2.25.0 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (2.28.1)
# Requirement already satisfied: packaging>=21.0 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (23.2)
# Requirement already satisfied: tomli>=2 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx==7.3.7->-r requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from sphinx_rtd_theme>=2.0.0->-r requirements.txt (line 7)) (4.1)
# Requirement already satisfied: markdown-it-py~=3.0 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from myst_parser>=0.18.0->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: mdit-py-plugins~=0.4 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from myst_parser>=0.18.0->-r requirements.txt (line 8)) (0.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from Jinja2>=3.0->sphinx==7.3.7->-r requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from markdown-it-py~=3.0->myst_parser>=0.18.0->-r requirements.txt (line 8)) (0.1.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from requests>=2.25.0->sphinx==7.3.7->-r requirements.txt (line 6)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from requests>=2.25.0->sphinx==7.3.7->-r requirements.txt (line 6)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from requests>=2.25.0->sphinx==7.3.7->-r requirements.txt (line 6)) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thoma\miniconda3\envs\py310\lib\site-packages (from requests>=2.25.0->sphinx==7.3.7->-r requirements.txt (line 6)) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Symlink to repo manager

# %%
# !!!!!!
# NOTE: This freezes and I don't think it's necessary because it appears to symlink regardless
# !!!!!!

# Symlink to repo manager

# os.chdir(tools_path)

# !python ./symlink_to_repo_manager.py

# %% [markdown]
# ## Build docs

# %% [markdown]
# ### Clean docs

# %%
os.chdir(docs_path)
# !make clean

# %% [markdown]
# ### Make docs

# %%
os.chdir(docs_path)
# !make html
# Out:
# Running Sphinx v7.3.7
# 📜 | [repo_manager] Reading manifest...
#    - Extension Src: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_extensions\sphinx_repo_manager'
#    - Manifest Src: 'D:\workspaces\multi_repo_docs\docs_update\docs\repo_manifest.yml'
# 🧹 | Validating & normalizing manifest...
#    - repo_sparse_path: 'docs'
# [conf.py::sphinx_repo_manager] Num repos found: 32
# loading pickled environment... done
# myst v3.0.1: MdParserConfig(commonmark_only=False, gfm_only=False, enable_extensions={'html_admonition', 'tasklist', 'smartquotes', 'strikethrough', 'amsmath', 'html_image', 'dollarmath', 'replacements', 'colon_fence'}, disable_syntax=[], all_links_external=False, links_external_new_tab=False, url_schemes=('http', 'https', 'mailto', 'ftp'), ref_domains=None, fence_as_directive=set(), number_code_blocks=[], title_to_header=False, heading_anchors=0, heading_slug_func=None, html_meta={}, footnote_transition=True, words_per_minute=200, substitutions={}, linkify_fuzzy_links=True, dmath_allow_labels=True, dmath_allow_space=True, dmath_allow_digits=True, dmath_double_inline=False, update_mathjax=True, mathjax_classes='tex2jax_process|mathjax_process|math|output_area', enable_checkboxes=False, suppress_warnings=[], highlight_code_blocks=True)
#
# ══BEGIN REPO_MANAGER══
#
# - working_dir (ABS_MANIFEST_PATH_DIR): 'D:\workspaces\multi_repo_docs\docs_update\docs'
# 📜 | [repo_manager] Reading manifest...
#    - Extension Src: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_extensions\sphinx_repo_manager'
#    - Manifest Src: 'D:\workspaces\multi_repo_docs\docs_update\docs\repo_manifest.yml'
# 🧹 | Validating & normalizing manifest...
#    - repo_sparse_path: 'docs'
# ⚙️ | Crafting dir skeleton from manifest...
#    - init_clone_path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available'
#    - base_symlink_path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content'
# 🤖 | Using 5 worker(s) for multi-threading
#   - CLI: `git -C 'source\_repos-available\xbe_static_docs--main' fetch --all --tags`
#   - CLI: `git -C 'source\_repos-available\account_services--dev' fetch --all --tags`
#   - CLI: `git -C 'source\_repos-available\achievements_services--dev' fetch --all --tags`
#   - CLI: `git -C 'source\_repos-available\asset_services--dev' fetch --all --tags`
#   - CLI: `git -C 'source\_repos-available\backup_services--dev' fetch --all --tags`
#   - CLI: `git -C 'source\_repos-available\xbe_static_docs--main' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\xbe_static_docs--main' checkout main`
#   - CLI: `git -C 'source\_repos-available\xbe_static_docs--main' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\xbe_static_docs--main' pull`
#   - Removing old symlink: 'source\content\-'
#   - New symlink created: 'source\content\-' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\xbe_static_docs--main\docs\source\content'
#
# -----------------------
# [Repo 1/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\xbe_static_docs--main'
#   - Repo symlink target path: 'source\content\-'
# [xbe_static_docs--main] 🔃 | Fetching updates...
# [xbe_static_docs--main] 🔄 | Checking out branch 'main'...
# [xbe_static_docs--main] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\xbe_static_docs--main\docs\source\content'
#   - To symlink path: 'docs/source/content'
# [xbe_static_docs--main] ✅ | Done.
#   - CLI: `git -C 'source\_repos-available\economy_services--dev' fetch --all --tags`
#   - CLI: `git -C 'source\_repos-available\asset_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\account_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\backup_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\achievements_services--dev' status --porcelain`
#   - Stashing WIP changes for repo: 'source\_repos-available\asset_services--dev'
#   - CLI: `git -C 'source\_repos-available\asset_services--dev' stash push -u -m repo_mgr-autostash`
#   - Stashing WIP changes for repo: 'source\_repos-available\account_services--dev'
#   - CLI: `git -C 'source\_repos-available\account_services--dev' stash push -u -m repo_mgr-autostash`
#   - Stashing WIP changes for repo: 'source\_repos-available\backup_services--dev'
#   - CLI: `git -C 'source\_repos-available\backup_services--dev' stash push -u -m repo_mgr-autostash`
#   - Stashing WIP changes for repo: 'source\_repos-available\achievements_services--dev'
#   - CLI: `git -C 'source\_repos-available\achievements_services--dev' stash push -u -m repo_mgr-autostash`
#   - CLI: `git -C 'source\_repos-available\asset_services--dev' checkout dev`
#   - CLI: `git -C 'source\_repos-available\account_services--dev' checkout dev`
#   - CLI: `git -C 'source\_repos-available\backup_services--dev' checkout dev`
#   - CLI: `git -C 'source\_repos-available\achievements_services--dev' checkout dev`
#   - CLI: `git -C 'source\_repos-available\account_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\backup_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\asset_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\achievements_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\asset_services--dev' pull`
#   - CLI: `git -C 'source\_repos-available\backup_services--dev' pull`
#   - CLI: `git -C 'source\_repos-available\account_services--dev' pull`
#   - CLI: `git -C 'source\_repos-available\economy_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\achievements_services--dev' pull`
#   - Stashing WIP changes for repo: 'source\_repos-available\economy_services--dev'
#   - CLI: `git -C 'source\_repos-available\economy_services--dev' stash push -u -m repo_mgr-autostash`
#   - CLI: `git -C 'source\_repos-available\economy_services--dev' checkout dev`
#   - CLI: `git -C 'source\_repos-available\economy_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\economy_services--dev' pull`
#   - Removing old symlink: 'source\content\asset_services'
#   - New symlink created: 'source\content\asset_services' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\asset_services--dev\docs\source'
#   - New symlink created: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content\asset_services\RELEASE_NOTES.rst' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\asset_services--dev\RELEASE_NOTES.rst'
#
# -----------------------
# [Repo 4/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\asset_services--dev'
#   - Repo symlink target path: 'source\content\asset_services'
# [asset_services--dev] 🔃 | Fetching updates...
# [asset_services--dev] 🔄 | Checking out branch 'dev'...
# [asset_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\asset_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [asset_services--dev] ✅ | Done.
#   - CLI: `git -C 'source\_repos-available\leaderboard_services--dev' fetch --all --tags`
#   - Removing old symlink: 'source\content\backup_services'
#   - New symlink created: 'source\content\backup_services' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\backup_services--dev\docs\source'
#   - New symlink created: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content\backup_services\RELEASE_NOTES.rst' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\backup_services--dev\RELEASE_NOTES.rst'
#
# -----------------------
# [Repo 5/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\backup_services--dev'
#   - Repo symlink target path: 'source\content\backup_services'
# [backup_services--dev] 🔃 | Fetching updates...
# [backup_services--dev] 🔄 | Checking out branch 'dev'...
# [backup_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\backup_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [backup_services--dev] ✅ | Done.
#   - CLI: `git -C 'source\_repos-available\matchmaking_services--dev' fetch --all --tags`
#   - Removing old symlink: 'source\content\account_services'
#   - Removing old symlink: 'source\content\achievements_services'
#   - New symlink created: 'source\content\account_services' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\account_services--dev\docs\source'
#   - New symlink created: 'source\content\achievements_services' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\achievements_services--dev\docs\source'
#   - New symlink created: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content\account_services\RELEASE_NOTES.rst' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\account_services--dev\RELEASE_NOTES.rst'
#
# -----------------------
# [Repo 2/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\account_services--dev'
#   - Repo symlink target path: 'source\content\account_services'
# [account_services--dev] 🔃 | Fetching updates...
# [account_services--dev] 🔄 | Checking out branch 'dev'...
# [account_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\account_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [account_services--dev] ✅ | Done.
#   - CLI: `git -C 'source\_repos-available\notification_services--dev' fetch --all --tags`
#   - New symlink created: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content\achievements_services\RELEASE_NOTES.rst' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\achievements_services--dev\RELEASE_NOTES.rst'
#
# -----------------------
# [Repo 3/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\achievements_services--dev'
#   - Repo symlink target path: 'source\content\achievements_services'
# [achievements_services--dev] 🔃 | Fetching updates...
# [achievements_services--dev] 🔄 | Checking out branch 'dev'...
# [achievements_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\achievements_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [achievements_services--dev] ✅ | Done.
#   - CLI: `git -C 'source\_repos-available\persona_services--dev' fetch --all --tags`
#   - Removing old symlink: 'source\content\economy_services'
#   - New symlink created: 'source\content\economy_services' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\economy_services--dev\docs\source'
#   - New symlink created: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content\economy_services\RELEASE_NOTES.rst' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\economy_services--dev\RELEASE_NOTES.rst'
#
# -----------------------
# [Repo 6/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\economy_services--dev'
#   - Repo symlink target path: 'source\content\economy_services'
# [economy_services--dev] 🔃 | Fetching updates...
# [economy_services--dev] 🔄 | Checking out branch 'dev'...
# [economy_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\economy_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [economy_services--dev] ✅ | Done.
#   - CLI: `git -C 'source\_repos-available\progression_services--dev' fetch --all --tags`
#   - CLI: `git -C 'source\_repos-available\matchmaking_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\leaderboard_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\notification_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\persona_services--dev' status --porcelain`
#   - Stashing WIP changes for repo: 'source\_repos-available\matchmaking_services--dev'
#   - CLI: `git -C 'source\_repos-available\matchmaking_services--dev' stash push -u -m repo_mgr-autostash`
#   - Stashing WIP changes for repo: 'source\_repos-available\leaderboard_services--dev'
#   - CLI: `git -C 'source\_repos-available\leaderboard_services--dev' stash push -u -m repo_mgr-autostash`
#   - Stashing WIP changes for repo: 'source\_repos-available\notification_services--dev'
#   - CLI: `git -C 'source\_repos-available\notification_services--dev' stash push -u -m repo_mgr-autostash`
#   - Stashing WIP changes for repo: 'source\_repos-available\persona_services--dev'
#   - CLI: `git -C 'source\_repos-available\persona_services--dev' stash push -u -m repo_mgr-autostash`
#   - CLI: `git -C 'source\_repos-available\progression_services--dev' status --porcelain`
#   - Stashing WIP changes for repo: 'source\_repos-available\progression_services--dev'
#   - CLI: `git -C 'source\_repos-available\progression_services--dev' stash push -u -m repo_mgr-autostash`
#   - CLI: `git -C 'source\_repos-available\matchmaking_services--dev' checkout dev`
#   - CLI: `git -C 'source\_repos-available\leaderboard_services--dev' checkout dev`
#   - CLI: `git -C 'source\_repos-available\persona_services--dev' checkout dev`
#   - CLI: `git -C 'source\_repos-available\notification_services--dev' checkout dev`
#   - CLI: `git -C 'source\_repos-available\matchmaking_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\leaderboard_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\persona_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\matchmaking_services--dev' pull`
#   - CLI: `git -C 'source\_repos-available\leaderboard_services--dev' pull`
#   - CLI: `git -C 'source\_repos-available\notification_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\persona_services--dev' pull`
#   - CLI: `git -C 'source\_repos-available\notification_services--dev' pull`
#   - CLI: `git -C 'source\_repos-available\progression_services--dev' checkout dev`
#   - CLI: `git -C 'source\_repos-available\progression_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\progression_services--dev' pull`
#   - Removing old symlink: 'source\content\persona_services'
#   - Removing old symlink: 'source\content\leaderboard_services'
#   - Removing old symlink: 'source\content\matchmaking_services'
#   - New symlink created: 'source\content\persona_services' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\persona_services--dev\docs\source'
#   - New symlink created: 'source\content\matchmaking_services' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\matchmaking_services--dev\docs\source'
#   - New symlink created: 'source\content\leaderboard_services' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\leaderboard_services--dev\docs\source'
#   - Removing old symlink: 'source\content\notification_services'
#   - New symlink created: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content\persona_services\RELEASE_NOTES.rst' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\persona_services--dev\RELEASE_NOTES.rst'
#
# -----------------------
# [Repo 10/32]
# 📁 | Working Dirs:
#   - New symlink created: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content\matchmaking_services\RELEASE_NOTES.rst' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\matchmaking_services--dev\RELEASE_NOTES.rst'
#   - Repo clone src path: 'source\_repos-available\persona_services--dev'
#   - Repo symlink target path: 'source\content\persona_services'
#
# -----------------------
# [Repo 8/32]
# [persona_services--dev] 🔃 | Fetching updates...
# 📁 | Working Dirs:
# [persona_services--dev] 🔄 | Checking out branch 'dev'...
#   - Repo clone src path: 'source\_repos-available\matchmaking_services--dev'
# [persona_services--dev] 🔗 | Symlinking...
#   - Repo symlink target path: 'source\content\matchmaking_services'
#   - New symlink created: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content\leaderboard_services\RELEASE_NOTES.rst' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\leaderboard_services--dev\RELEASE_NOTES.rst'
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\persona_services--dev\docs\source'
# [matchmaking_services--dev] 🔃 | Fetching updates...
#   - To symlink path: 'docs/source'
#
# -----------------------
# [Repo 7/32]
# [matchmaking_services--dev] 🔄 | Checking out branch 'dev'...
# [persona_services--dev] ✅ | Done.
# 📁 | Working Dirs:
# [matchmaking_services--dev] 🔗 | Symlinking...
#   - New symlink created: 'source\content\notification_services' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\notification_services--dev\docs\source'
#   - Repo clone src path: 'source\_repos-available\leaderboard_services--dev'
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\matchmaking_services--dev\docs\source'
#   - CLI: `git -C 'source\_repos-available\purchasing_services--dev' fetch --all --tags`
#   - Repo symlink target path: 'source\content\leaderboard_services'
#   - To symlink path: 'docs/source'
# [leaderboard_services--dev] 🔃 | Fetching updates...
# [matchmaking_services--dev] ✅ | Done.
# [leaderboard_services--dev] 🔄 | Checking out branch 'dev'...
# [leaderboard_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\leaderboard_services--dev\docs\source'
#   - CLI: `git -C 'source\_repos-available\quest_services--dev' fetch --all --tags`
#   - To symlink path: 'docs/source'
# [leaderboard_services--dev] ✅ | Done.
#   - New symlink created: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content\notification_services\RELEASE_NOTES.rst' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\notification_services--dev\RELEASE_NOTES.rst'
#   - CLI: `git -C 'source\_repos-available\reporting_services--dev' fetch --all --tags`
#
# -----------------------
# [Repo 9/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\notification_services--dev'
#   - Repo symlink target path: 'source\content\notification_services'
# [notification_services--dev] 🔃 | Fetching updates...
# [notification_services--dev] 🔄 | Checking out branch 'dev'...
# [notification_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\notification_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [notification_services--dev] ✅ | Done.
#   - CLI: `git -C 'source\_repos-available\scripting_services--dev' fetch --all --tags`
#   - Removing old symlink: 'source\content\progression_services'
#   - New symlink created: 'source\content\progression_services' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\progression_services--dev\docs\source'
#   - New symlink created: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content\progression_services\RELEASE_NOTES.rst' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\progression_services--dev\RELEASE_NOTES.rst'
#
# -----------------------
# [Repo 11/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\progression_services--dev'
#   - Repo symlink target path: 'source\content\progression_services'
# [progression_services--dev] 🔃 | Fetching updates...
# [progression_services--dev] 🔄 | Checking out branch 'dev'...
# [progression_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\progression_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [progression_services--dev] ✅ | Done.
#   - CLI: `git -C 'source\_repos-available\server_instance_services--dev' fetch --all --tags`
#   - CLI: `git -C 'source\_repos-available\scripting_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\quest_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\reporting_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\purchasing_services--dev' status --porcelain`
#   - Stashing WIP changes for repo: 'source\_repos-available\quest_services--dev'
#   - Stashing WIP changes for repo: 'source\_repos-available\scripting_services--dev'
#   - CLI: `git -C 'source\_repos-available\quest_services--dev' stash push -u -m repo_mgr-autostash`
#   - CLI: `git -C 'source\_repos-available\scripting_services--dev' stash push -u -m repo_mgr-autostash`
#   - CLI: `git -C 'source\_repos-available\server_instance_services--dev' status --porcelain`
#   - Stashing WIP changes for repo: 'source\_repos-available\purchasing_services--dev'
#   - CLI: `git -C 'source\_repos-available\purchasing_services--dev' stash push -u -m repo_mgr-autostash`
#   - Stashing WIP changes for repo: 'source\_repos-available\reporting_services--dev'
#   - CLI: `git -C 'source\_repos-available\reporting_services--dev' stash push -u -m repo_mgr-autostash`
#   - Stashing WIP changes for repo: 'source\_repos-available\server_instance_services--dev'
#   - CLI: `git -C 'source\_repos-available\server_instance_services--dev' stash push -u -m repo_mgr-autostash`
#   - CLI: `git -C 'source\_repos-available\reporting_services--dev' checkout dev`
#   - CLI: `git -C 'source\_repos-available\quest_services--dev' checkout dev`
#   - CLI: `git -C 'source\_repos-available\scripting_services--dev' checkout dev`
#   - CLI: `git -C 'source\_repos-available\purchasing_services--dev' checkout dev`
#   - CLI: `git -C 'source\_repos-available\server_instance_services--dev' checkout dev`
#   - CLI: `git -C 'source\_repos-available\reporting_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\quest_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\reporting_services--dev' pull`
#   - CLI: `git -C 'source\_repos-available\quest_services--dev' pull`
#   - CLI: `git -C 'source\_repos-available\scripting_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\server_instance_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\purchasing_services--dev' status --porcelain`
#   - CLI: `git -C 'source\_repos-available\scripting_services--dev' pull`
#   - CLI: `git -C 'source\_repos-available\server_instance_services--dev' pull`
#   - CLI: `git -C 'source\_repos-available\purchasing_services--dev' pull`
#   - Removing old symlink: 'source\content\reporting_services'
#   - New symlink created: 'source\content\reporting_services' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\reporting_services--dev\docs\source'
#   - New symlink created: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content\reporting_services\RELEASE_NOTES.rst' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\reporting_services--dev\RELEASE_NOTES.rst'
#
# -----------------------
# [Repo 14/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\reporting_services--dev'
#   - Repo symlink target path: 'source\content\reporting_services'
# [reporting_services--dev] 🔃 | Fetching updates...
# [reporting_services--dev] 🔄 | Checking out branch 'dev'...
# [reporting_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\reporting_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [reporting_services--dev] ✅ | Done.
#   - CLI: `git -C 'source\_repos-available\session_services--dev' fetch --all --tags`
#   - Removing old symlink: 'source\content\quest_services'
#   - New symlink created: 'source\content\quest_services' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\quest_services--dev\docs\source'
#   - New symlink created: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content\quest_services\RELEASE_NOTES.rst' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\quest_services--dev\RELEASE_NOTES.rst'
#
# -----------------------
# [Repo 13/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\quest_services--dev'
#   - Repo symlink target path: 'source\content\quest_services'
# [quest_services--dev] 🔃 | Fetching updates...
# [quest_services--dev] 🔄 | Checking out branch 'dev'...
# [quest_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\quest_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [quest_services--dev] ✅ | Done.
#   - CLI: `git -C 'source\_repos-available\social_services--dev' fetch --all --tags`
#   - Removing old symlink: 'source\content\purchasing_services'
#   - Removing old symlink: 'source\content\server_instance_services'
#   - Removing old symlink: 'source\content\scripting_services'
#   - New symlink created: 'source\content\purchasing_services' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\purchasing_services--dev\docs\source'
#   - New symlink created: 'source\content\scripting_services' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\scripting_services--dev\docs\source'
#   - New symlink created: 'source\content\server_instance_services' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\server_instance_services--dev\docs\source'
#   - New symlink created: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content\purchasing_services\RELEASE_NOTES.rst' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\purchasing_services--dev\RELEASE_NOTES.rst'
#   - New symlink created: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content\scripting_services\RELEASE_NOTES.rst' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\scripting_services--dev\RELEASE_NOTES.rst'
#
# -----------------------
# [Repo 12/32]
#   - New symlink created: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\content\server_instance_services\RELEASE_NOTES.rst' -> 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\server_instance_services--dev\RELEASE_NOTES.rst'
# 📁 | Working Dirs:
#
# -----------------------
# [Repo 15/32]
#   - Repo clone src path: 'source\_repos-available\purchasing_services--dev'
#
# -----------------------
# [Repo 16/32]
# 📁 | Working Dirs:
#   - Repo symlink target path: 'source\content\purchasing_services'
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\scripting_services--dev'
# [purchasing_services--dev] 🔃 | Fetching updates...
#   - Repo clone src path: 'source\_repos-available\server_instance_services--dev'
#   - Repo symlink target path: 'source\content\scripting_services'
# [purchasing_services--dev] 🔄 | Checking out branch 'dev'...
#   - Repo symlink target path: 'source\content\server_instance_services'
# [scripting_services--dev] 🔃 | Fetching updates...
# [purchasing_services--dev] 🔗 | Symlinking...
# [server_instance_services--dev] 🔃 | Fetching updates...
# [scripting_services--dev] 🔄 | Checking out branch 'dev'...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\purchasing_services--dev\docs\source'
# [server_instance_services--dev] 🔄 | Checking out branch 'dev'...
# [scripting_services--dev] 🔗 | Symlinking...
#   - To symlink path: 'docs/source'
# [server_instance_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\scripting_services--dev\docs\source'
# [purchasing_services--dev] ✅ | Done.
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\server_instance_services--dev\docs\source'
#   - To symlink path: 'docs/source'
#   - To symlink path: 'docs/source'
# [scripting_services--dev] ✅ | Done.
#   - CLI: `git -C 'source\_repos-available\telemetry_services--dev' fetch --all --tags`
# [server_instance_services--dev] ✅ | Done.
#   - CLI: `git -C 'source\_repos-available\validation_services--dev' fetch --all --tags`
#   - CLI: `git -C 'source\_repos-available\sdk_cpp--dev_vcpkg_update' fetch --all --tags`
#
# -----------------------
# [Repo 21/32]
# 📁 | Working Dirs:
#
# -----------------------
# [Repo 19/32]
#   - Repo clone src path: 'source\_repos-available\sdk_cpp--dev_vcpkg_update'
#
# -----------------------
# [Repo 20/32]
# 📁 | Working Dirs:
#   - Repo symlink target path: 'source\content\sdk_cpp'
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\telemetry_services--dev'
# [sdk_cpp--dev_vcpkg_update] 🔃 | Fetching updates...
#   - Repo clone src path: 'source\_repos-available\validation_services--dev'
#   - Repo symlink target path: 'source\content\telemetry_services'
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\sdk_cpp'
# - Error: Command failed: 'git -C 'source\_repos-available\sdk_cpp--dev_vcpkg_update' fetch --all --tags'
# Error: 'fatal: cannot change to 'source\_repos-available\sdk_cpp--dev_vcpkg_update': No such file or directory'
#
#
#   - Repo symlink target path: 'source\content\validation_services'
# [telemetry_services--dev] 🔃 | Fetching updates...
# [validation_services--dev] 🔃 | Fetching updates...
#   - CLI: `git -C 'source\_repos-available\sdk_csharp--dev' fetch --all --tags`
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\telemetry_services'
# - Error: Command failed: 'git -C 'source\_repos-available\telemetry_services--dev' fetch --all --tags'
# Error: 'fatal: cannot change to 'source\_repos-available\telemetry_services--dev': No such file or directory'
#
#
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\validation_services'
# - Error: Command failed: 'git -C 'source\_repos-available\validation_services--dev' fetch --all --tags'
# Error: 'fatal: cannot change to 'source\_repos-available\validation_services--dev': No such file or directory'
#
#
#   - CLI: `git -C 'source\_repos-available\sdk_nodejs--dev' fetch --all --tags`
#   - CLI: `git -C 'source\_repos-available\sdk_unity--dev' fetch --all --tags`
#
# -----------------------
# [Repo 22/32]
# 📁 | Working Dirs:
#
# -----------------------
# [Repo 24/32]
#   - Repo clone src path: 'source\_repos-available\sdk_csharp--dev'
# 📁 | Working Dirs:
#
# -----------------------
# [Repo 23/32]
#   - Repo symlink target path: 'source\content\sdk_csharp'
#   - Repo clone src path: 'source\_repos-available\sdk_unity--dev'
# 📁 | Working Dirs:
# [sdk_csharp--dev] 🔃 | Fetching updates...
#   - Repo symlink target path: 'source\content\sdk_unity'
#   - Repo clone src path: 'source\_repos-available\sdk_nodejs--dev'
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\sdk_csharp'
# - Error: Command failed: 'git -C 'source\_repos-available\sdk_csharp--dev' fetch --all --tags'
# Error: 'fatal: cannot change to 'source\_repos-available\sdk_csharp--dev': No such file or directory'
#
#
# [sdk_unity--dev] 🔃 | Fetching updates...
#   - Repo symlink target path: 'source\content\sdk_nodejs'
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\sdk_unity'
# - Error: Command failed: 'git -C 'source\_repos-available\sdk_unity--dev' fetch --all --tags'
# Error: 'fatal: cannot change to 'source\_repos-available\sdk_unity--dev': No such file or directory'
#
#
# [sdk_nodejs--dev] 🔃 | Fetching updates...
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\sdk_nodejs'
# - Error: Command failed: 'git -C 'source\_repos-available\sdk_nodejs--dev' fetch --all --tags'
# Error: 'fatal: cannot change to 'source\_repos-available\sdk_nodejs--dev': No such file or directory'
#
#
#   - CLI: `git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/acceleratxr/composerjs/service-core.git 'source\_repos-available\service-core--dev'`
#   - CLI: `git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/sdk/sdk_unreal.git 'source\_repos-available\sdk_unreal--dev'`
#   - CLI: `git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/service_monitor.git 'source\_repos-available\service_monitor--dev'`
#
# -----------------------
# [Repo 26/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\service-core--dev'
#   - Repo symlink target path: 'source\content\service-core'
# [service-core--dev] 📦 | Sparse-cloning repo...
#   - Src Repo URL: 'source\_repos-available\service-core--dev'
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\service-core'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/acceleratxr/composerjs/service-core.git 'source\_repos-available\service-core--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\service-core--dev': No such file or directory'
#
#
#   - CLI: `git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/apps/launcher.git 'source\_repos-available\launcher--dev'`
#
# -----------------------
# [Repo 27/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\service_monitor--dev'
#   - Repo symlink target path: 'source\content\service_monitor'
# [service_monitor--dev] 📦 | Sparse-cloning repo...
#
# -----------------------
# [Repo 25/32]
#   - Src Repo URL: 'source\_repos-available\service_monitor--dev'
# 📁 | Working Dirs:
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\service_monitor'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/service_monitor.git 'source\_repos-available\service_monitor--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\service_monitor--dev': No such file or directory'
#
#
#   - Repo clone src path: 'source\_repos-available\sdk_unreal--dev'
#   - CLI: `git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/apps/console.git 'source\_repos-available\console--dev'`
#   - Repo symlink target path: 'source\content\sdk_unreal'
# [sdk_unreal--dev] 📦 | Sparse-cloning repo...
#   - Src Repo URL: 'source\_repos-available\sdk_unreal--dev'
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\sdk_unreal'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/sdk/sdk_unreal.git 'source\_repos-available\sdk_unreal--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\sdk_unreal--dev': No such file or directory'
#
#
#   - CLI: `git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/acceleratxr/apps/xbeapp.git 'source\_repos-available\xbeapp--dev'`
#
# -----------------------
# [Repo 17/32]
# 📁 | Working Dirs:
#
# -----------------------
# [Repo 18/32]
#   - Repo clone src path: 'source\_repos-available\session_services--dev'
# 📁 | Working Dirs:
#   - Repo symlink target path: 'source\content\session_services'
#   - Repo clone src path: 'source\_repos-available\social_services--dev'
# [session_services--dev] 🔃 | Fetching updates...
#   - Repo symlink target path: 'source\content\social_services'
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\session_services'
# - Error: Command failed: 'git -C 'source\_repos-available\session_services--dev' fetch --all --tags'
# Error: 'Unhandled Exception: System.ComponentModel.Win32Exception: The directory name is invalid
#    at System.Diagnostics.Process.StartWithCreateProcess(ProcessStartInfo startInfo)
#    at System.Diagnostics.Process.Start()
#    at GitCredentialManager.ChildProcess.Start(Trace2ProcessClass processClass)
#    at GitCredentialManager.GitProcessConfiguration.Enumerate(GitConfigurationLevel level, GitConfigurationEnumerationCallback cb)
#    at GitCredentialManager.GitConfigurationExtensions.Enumerate(IGitConfiguration config, GitConfigurationEnumerationCallback cb)
#    at GitCredentialManager.Settings.<GetSettingValues>d__6.MoveNext()
#    at System.Linq.Enumerable.FirstOrDefault[TSource](IEnumerable`1 source)
#    at GitCredentialManager.Settings.TryGetSetting(String envarName, String section, String property, String& value)
#    at GitCredentialManager.Settings.GetTrace2Settings()
#    at GitCredentialManager.Trace2.Initialize(DateTimeOffset startTime)
#    at GitCredentialManager.Program.AppMain(Object o)
#    at System.Threading.ThreadHelper.ThreadStart_Context(Object state)
#    at System.Threading.ExecutionContext.RunInternal(ExecutionContext executionContext, ContextCallback callback, Object state, Boolean preserveSyncCtx)
#    at System.Threading.ExecutionContext.Run(ExecutionContext executionContext, ContextCallback callback, Object state, Boolean preserveSyncCtx)
#    at System.Threading.ExecutionContext.Run(ExecutionContext executionContext, ContextCallback callback, Object state)
#    at System.Threading.ThreadHelper.ThreadStart(Object obj)
# bash: line 1: /dev/tty: No such device or address
# error: failed to execute prompt script (exit code 1)
# fatal: could not read Username for 'https://gitlab.acceleratxr.com': No such file or directory'
#
#
# [social_services--dev] 🔃 | Fetching updates...
#   - CLI: `git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/samples/unitychessgame.git 'source\_repos-available\unitychessgame--dev'`
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\social_services'
# - Error: Command failed: 'git -C 'source\_repos-available\social_services--dev' fetch --all --tags'
# Error: 'Unhandled Exception: System.ComponentModel.Win32Exception: The directory name is invalid
#    at System.Diagnostics.Process.StartWithCreateProcess(ProcessStartInfo startInfo)
#    at System.Diagnostics.Process.Start()
#    at GitCredentialManager.ChildProcess.Start(Trace2ProcessClass processClass)
#    at GitCredentialManager.GitProcessConfiguration.Enumerate(GitConfigurationLevel level, GitConfigurationEnumerationCallback cb)
#    at GitCredentialManager.GitConfigurationExtensions.Enumerate(IGitConfiguration config, GitConfigurationEnumerationCallback cb)
#    at GitCredentialManager.Settings.<GetSettingValues>d__6.MoveNext()
#    at System.Linq.Enumerable.FirstOrDefault[TSource](IEnumerable`1 source)
#    at GitCredentialManager.Settings.TryGetSetting(String envarName, String section, String property, String& value)
#    at GitCredentialManager.Settings.GetTrace2Settings()
#    at GitCredentialManager.Trace2.Initialize(DateTimeOffset startTime)
#    at GitCredentialManager.Program.AppMain(Object o)
#    at System.Threading.ThreadHelper.ThreadStart_Context(Object state)
#    at System.Threading.ExecutionContext.RunInternal(ExecutionContext executionContext, ContextCallback callback, Object state, Boolean preserveSyncCtx)
#    at System.Threading.ExecutionContext.Run(ExecutionContext executionContext, ContextCallback callback, Object state, Boolean preserveSyncCtx)
#    at System.Threading.ExecutionContext.Run(ExecutionContext executionContext, ContextCallback callback, Object state)
#    at System.Threading.ThreadHelper.ThreadStart(Object obj)
# bash: line 1: /dev/tty: No such device or address
# error: failed to execute prompt script (exit code 1)
# fatal: could not read Username for 'https://gitlab.acceleratxr.com': No such file or directory'
#
#
#   - CLI: `git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/samples/lyrastartergame.git 'source\_repos-available\lyrastartergame--dev'`
#
# -----------------------
# [Repo 29/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\console--dev'
#   - Repo symlink target path: 'source\content\console'
# [console--dev] 📦 | Sparse-cloning repo...
#   - Src Repo URL: 'source\_repos-available\console--dev'
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\console'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/apps/console.git 'source\_repos-available\console--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\console--dev': No such file or directory'
#
#
#
# -----------------------
# [Repo 30/32]
# 📁 | Working Dirs:
#
# -----------------------
# [Repo 28/32]
#   - Repo clone src path: 'source\_repos-available\xbeapp--dev'
# 📁 | Working Dirs:
#   - Repo symlink target path: 'source\content\xbeapp'
#   - Repo clone src path: 'source\_repos-available\launcher--dev'
# [xbeapp--dev] 📦 | Sparse-cloning repo...
#   - Repo symlink target path: 'source\content\launcher'
#   - Src Repo URL: 'source\_repos-available\xbeapp--dev'
# [launcher--dev] 📦 | Sparse-cloning repo...
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\xbeapp'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/acceleratxr/apps/xbeapp.git 'source\_repos-available\xbeapp--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\xbeapp--dev': No such file or directory'
#
#
#   - Src Repo URL: 'source\_repos-available\launcher--dev'
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\launcher'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/apps/launcher.git 'source\_repos-available\launcher--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\launcher--dev': No such file or directory'
#
#
#
# -----------------------
# [Repo 32/32]
# 📁 | Working Dirs:
#
# -----------------------
# [Repo 31/32]
#   - Repo clone src path: 'source\_repos-available\lyrastartergame--dev'
# 📁 | Working Dirs:
#   - Repo symlink target path: 'source\content\lyrastartergame'
#   - Repo clone src path: 'source\_repos-available\unitychessgame--dev'
# [lyrastartergame--dev] 📦 | Sparse-cloning repo...
#   - Repo symlink target path: 'source\content\unitychessgame'
#   - Src Repo URL: 'source\_repos-available\lyrastartergame--dev'
# [unitychessgame--dev] 📦 | Sparse-cloning repo...
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\lyrastartergame'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/samples/lyrastartergame.git 'source\_repos-available\lyrastartergame--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\lyrastartergame--dev': No such file or directory'
#
#
#   - Src Repo URL: 'source\_repos-available\unitychessgame--dev'
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\unitychessgame'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/samples/unitychessgame.git 'source\_repos-available\unitychessgame--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\unitychessgame--dev': No such file or directory'
#
#
#
# -----------------------
# [Repo 1/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\xbe_static_docs--main'
#   - Repo symlink target path: 'source\content\-'
# [xbe_static_docs--main] 🔃 | Fetching updates...
# [xbe_static_docs--main] 🔄 | Checking out branch 'main'...
# [xbe_static_docs--main] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\xbe_static_docs--main\docs\source\content'
#   - To symlink path: 'docs/source/content'
# [xbe_static_docs--main] ✅ | Done.
#
# -----------------------
# [Repo 4/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\asset_services--dev'
#   - Repo symlink target path: 'source\content\asset_services'
# [asset_services--dev] 🔃 | Fetching updates...
# [asset_services--dev] 🔄 | Checking out branch 'dev'...
# [asset_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\asset_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [asset_services--dev] ✅ | Done.
#
# -----------------------
# [Repo 5/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\backup_services--dev'
#   - Repo symlink target path: 'source\content\backup_services'
# [backup_services--dev] 🔃 | Fetching updates...
# [backup_services--dev] 🔄 | Checking out branch 'dev'...
# [backup_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\backup_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [backup_services--dev] ✅ | Done.
#
# -----------------------
# [Repo 2/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\account_services--dev'
#   - Repo symlink target path: 'source\content\account_services'
# [account_services--dev] 🔃 | Fetching updates...
# [account_services--dev] 🔄 | Checking out branch 'dev'...
# [account_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\account_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [account_services--dev] ✅ | Done.
#
# -----------------------
# [Repo 3/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\achievements_services--dev'
#   - Repo symlink target path: 'source\content\achievements_services'
# [achievements_services--dev] 🔃 | Fetching updates...
# [achievements_services--dev] 🔄 | Checking out branch 'dev'...
# [achievements_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\achievements_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [achievements_services--dev] ✅ | Done.
#
# -----------------------
# [Repo 6/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\economy_services--dev'
#   - Repo symlink target path: 'source\content\economy_services'
# [economy_services--dev] 🔃 | Fetching updates...
# [economy_services--dev] 🔄 | Checking out branch 'dev'...
# [economy_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\economy_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [economy_services--dev] ✅ | Done.
#
# -----------------------
# [Repo 10/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\persona_services--dev'
#   - Repo symlink target path: 'source\content\persona_services'
# [persona_services--dev] 🔃 | Fetching updates...
# [persona_services--dev] 🔄 | Checking out branch 'dev'...
# [persona_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\persona_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [persona_services--dev] ✅ | Done.
#
# -----------------------
# [Repo 8/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\matchmaking_services--dev'
#   - Repo symlink target path: 'source\content\matchmaking_services'
# [matchmaking_services--dev] 🔃 | Fetching updates...
# [matchmaking_services--dev] 🔄 | Checking out branch 'dev'...
# [matchmaking_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\matchmaking_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [matchmaking_services--dev] ✅ | Done.
#
# -----------------------
# [Repo 7/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\leaderboard_services--dev'
#   - Repo symlink target path: 'source\content\leaderboard_services'
# [leaderboard_services--dev] 🔃 | Fetching updates...
# [leaderboard_services--dev] 🔄 | Checking out branch 'dev'...
# [leaderboard_services--dev] 🔗 | Symlinking...
#   - From clone src path: 'D:\workspaces\multi_repo_docs\docs_update\docs\source\_repos-available\leaderboard_services--dev\docs\source'
#   - To symlink path: 'docs/source'
# [leaderboard_services--dev] ✅ | Done.
#
# -----------------------
# [Repo 9/32]
# 📁 | Working Dirs:
#   - Repo clone src path: 'source\_repos-available\notification_services--dev'
# ...
# ERROR: Command failed:
# fatal: cannot change to 'source\_repos-available\sdk_nodejs--dev': No such file or directory
# ERROR: Failed to manage repository:
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\sdk_csharp'
# - Error: Command failed: 'git -C 'source\_repos-available\sdk_csharp--dev' fetch --all --tags'
# Error: 'fatal: cannot change to 'source\_repos-available\sdk_csharp--dev': No such file or directory'
#
#
# ERROR: Failed to manage repository:
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\sdk_unity'
# - Error: Command failed: 'git -C 'source\_repos-available\sdk_unity--dev' fetch --all --tags'
# Error: 'fatal: cannot change to 'source\_repos-available\sdk_unity--dev': No such file or directory'
#
#
# ERROR: Failed to manage repository:
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\sdk_nodejs'
# - Error: Command failed: 'git -C 'source\_repos-available\sdk_nodejs--dev' fetch --all --tags'
# Error: 'fatal: cannot change to 'source\_repos-available\sdk_nodejs--dev': No such file or directory'
#
#
# ERROR: Command failed:
# fatal: could not create leading directories of 'source\_repos-available\service-core--dev': No such file or directory
# ERROR: Failed to manage repository:
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\service-core'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/acceleratxr/composerjs/service-core.git 'source\_repos-available\service-core--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\service-core--dev': No such file or directory'
#
#
# ERROR: Command failed:
# fatal: could not create leading directories of 'source\_repos-available\service_monitor--dev': No such file or directory
# ERROR: Command failed:
# fatal: could not create leading directories of 'source\_repos-available\sdk_unreal--dev': No such file or directory
# ERROR: Failed to manage repository:
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\service_monitor'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/service_monitor.git 'source\_repos-available\service_monitor--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\service_monitor--dev': No such file or directory'
#
#
# ERROR: Failed to manage repository:
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\sdk_unreal'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/sdk/sdk_unreal.git 'source\_repos-available\sdk_unreal--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\sdk_unreal--dev': No such file or directory'
#
#
# ERROR: Command failed:
# Unhandled Exception: System.ComponentModel.Win32Exception: The directory name is invalid
#    at System.Diagnostics.Process.StartWithCreateProcess(ProcessStartInfo startInfo)
#    at System.Diagnostics.Process.Start()
#    at GitCredentialManager.ChildProcess.Start(Trace2ProcessClass processClass)
#    at GitCredentialManager.GitProcessConfiguration.Enumerate(GitConfigurationLevel level, GitConfigurationEnumerationCallback cb)
#    at GitCredentialManager.GitConfigurationExtensions.Enumerate(IGitConfiguration config, GitConfigurationEnumerationCallback cb)
#    at GitCredentialManager.Settings.<GetSettingValues>d__6.MoveNext()
#    at System.Linq.Enumerable.FirstOrDefault[TSource](IEnumerable`1 source)
#    at GitCredentialManager.Settings.TryGetSetting(String envarName, String section, String property, String& value)
#    at GitCredentialManager.Settings.GetTrace2Settings()
#    at GitCredentialManager.Trace2.Initialize(DateTimeOffset startTime)
#    at GitCredentialManager.Program.AppMain(Object o)
#    at System.Threading.ThreadHelper.ThreadStart_Context(Object state)
#    at System.Threading.ExecutionContext.RunInternal(ExecutionContext executionContext, ContextCallback callback, Object state, Boolean preserveSyncCtx)
#    at System.Threading.ExecutionContext.Run(ExecutionContext executionContext, ContextCallback callback, Object state, Boolean preserveSyncCtx)
#    at System.Threading.ExecutionContext.Run(ExecutionContext executionContext, ContextCallback callback, Object state)
#    at System.Threading.ThreadHelper.ThreadStart(Object obj)
# bash: line 1: /dev/tty: No such device or address
# error: failed to execute prompt script (exit code 1)
# fatal: could not read Username for 'https://gitlab.acceleratxr.com': No such file or directory
# ERROR: Command failed:
# Unhandled Exception: System.ComponentModel.Win32Exception: The directory name is invalid
#    at System.Diagnostics.Process.StartWithCreateProcess(ProcessStartInfo startInfo)
#    at System.Diagnostics.Process.Start()
#    at GitCredentialManager.ChildProcess.Start(Trace2ProcessClass processClass)
#    at GitCredentialManager.GitProcessConfiguration.Enumerate(GitConfigurationLevel level, GitConfigurationEnumerationCallback cb)
#    at GitCredentialManager.GitConfigurationExtensions.Enumerate(IGitConfiguration config, GitConfigurationEnumerationCallback cb)
#    at GitCredentialManager.Settings.<GetSettingValues>d__6.MoveNext()
#    at System.Linq.Enumerable.FirstOrDefault[TSource](IEnumerable`1 source)
#    at GitCredentialManager.Settings.TryGetSetting(String envarName, String section, String property, String& value)
#    at GitCredentialManager.Settings.GetTrace2Settings()
#    at GitCredentialManager.Trace2.Initialize(DateTimeOffset startTime)
#    at GitCredentialManager.Program.AppMain(Object o)
#    at System.Threading.ThreadHelper.ThreadStart_Context(Object state)
#    at System.Threading.ExecutionContext.RunInternal(ExecutionContext executionContext, ContextCallback callback, Object state, Boolean preserveSyncCtx)
#    at System.Threading.ExecutionContext.Run(ExecutionContext executionContext, ContextCallback callback, Object state, Boolean preserveSyncCtx)
#    at System.Threading.ExecutionContext.Run(ExecutionContext executionContext, ContextCallback callback, Object state)
#    at System.Threading.ThreadHelper.ThreadStart(Object obj)
# bash: line 1: /dev/tty: No such device or address
# error: failed to execute prompt script (exit code 1)
# fatal: could not read Username for 'https://gitlab.acceleratxr.com': No such file or directory
# ERROR: Failed to manage repository:
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\session_services'
# - Error: Command failed: 'git -C 'source\_repos-available\session_services--dev' fetch --all --tags'
# Error: 'Unhandled Exception: System.ComponentModel.Win32Exception: The directory name is invalid
#    at System.Diagnostics.Process.StartWithCreateProcess(ProcessStartInfo startInfo)
#    at System.Diagnostics.Process.Start()
#    at GitCredentialManager.ChildProcess.Start(Trace2ProcessClass processClass)
#    at GitCredentialManager.GitProcessConfiguration.Enumerate(GitConfigurationLevel level, GitConfigurationEnumerationCallback cb)
#    at GitCredentialManager.GitConfigurationExtensions.Enumerate(IGitConfiguration config, GitConfigurationEnumerationCallback cb)
#    at GitCredentialManager.Settings.<GetSettingValues>d__6.MoveNext()
#    at System.Linq.Enumerable.FirstOrDefault[TSource](IEnumerable`1 source)
#    at GitCredentialManager.Settings.TryGetSetting(String envarName, String section, String property, String& value)
#    at GitCredentialManager.Settings.GetTrace2Settings()
#    at GitCredentialManager.Trace2.Initialize(DateTimeOffset startTime)
#    at GitCredentialManager.Program.AppMain(Object o)
#    at System.Threading.ThreadHelper.ThreadStart_Context(Object state)
#    at System.Threading.ExecutionContext.RunInternal(ExecutionContext executionContext, ContextCallback callback, Object state, Boolean preserveSyncCtx)
#    at System.Threading.ExecutionContext.Run(ExecutionContext executionContext, ContextCallback callback, Object state, Boolean preserveSyncCtx)
#    at System.Threading.ExecutionContext.Run(ExecutionContext executionContext, ContextCallback callback, Object state)
#    at System.Threading.ThreadHelper.ThreadStart(Object obj)
# bash: line 1: /dev/tty: No such device or address
# error: failed to execute prompt script (exit code 1)
# fatal: could not read Username for 'https://gitlab.acceleratxr.com': No such file or directory'
#
#
# ERROR: Failed to manage repository:
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\social_services'
# - Error: Command failed: 'git -C 'source\_repos-available\social_services--dev' fetch --all --tags'
# Error: 'Unhandled Exception: System.ComponentModel.Win32Exception: The directory name is invalid
#    at System.Diagnostics.Process.StartWithCreateProcess(ProcessStartInfo startInfo)
#    at System.Diagnostics.Process.Start()
#    at GitCredentialManager.ChildProcess.Start(Trace2ProcessClass processClass)
#    at GitCredentialManager.GitProcessConfiguration.Enumerate(GitConfigurationLevel level, GitConfigurationEnumerationCallback cb)
#    at GitCredentialManager.GitConfigurationExtensions.Enumerate(IGitConfiguration config, GitConfigurationEnumerationCallback cb)
#    at GitCredentialManager.Settings.<GetSettingValues>d__6.MoveNext()
#    at System.Linq.Enumerable.FirstOrDefault[TSource](IEnumerable`1 source)
#    at GitCredentialManager.Settings.TryGetSetting(String envarName, String section, String property, String& value)
#    at GitCredentialManager.Settings.GetTrace2Settings()
#    at GitCredentialManager.Trace2.Initialize(DateTimeOffset startTime)
#    at GitCredentialManager.Program.AppMain(Object o)
#    at System.Threading.ThreadHelper.ThreadStart_Context(Object state)
#    at System.Threading.ExecutionContext.RunInternal(ExecutionContext executionContext, ContextCallback callback, Object state, Boolean preserveSyncCtx)
#    at System.Threading.ExecutionContext.Run(ExecutionContext executionContext, ContextCallback callback, Object state, Boolean preserveSyncCtx)
#    at System.Threading.ExecutionContext.Run(ExecutionContext executionContext, ContextCallback callback, Object state)
#    at System.Threading.ThreadHelper.ThreadStart(Object obj)
# bash: line 1: /dev/tty: No such device or address
# error: failed to execute prompt script (exit code 1)
# fatal: could not read Username for 'https://gitlab.acceleratxr.com': No such file or directory'
#
#
# ERROR: Command failed:
# fatal: could not create leading directories of 'source\_repos-available\console--dev': No such file or directory
# ERROR: Failed to manage repository:
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\console'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/apps/console.git 'source\_repos-available\console--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\console--dev': No such file or directory'
#
#
# ERROR: Command failed:
# fatal: could not create leading directories of 'source\_repos-available\xbeapp--dev': No such file or directory
# ERROR: Command failed:
# fatal: could not create leading directories of 'source\_repos-available\launcher--dev': No such file or directory
# ERROR: Failed to manage repository:
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\xbeapp'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/acceleratxr/apps/xbeapp.git 'source\_repos-available\xbeapp--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\xbeapp--dev': No such file or directory'
#
#
# ERROR: Failed to manage repository:
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\launcher'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/apps/launcher.git 'source\_repos-available\launcher--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\launcher--dev': No such file or directory'
#
#
# ERROR: Command failed:
# fatal: could not create leading directories of 'source\_repos-available\lyrastartergame--dev': No such file or directory
# ERROR: Command failed:
# fatal: could not create leading directories of 'source\_repos-available\unitychessgame--dev': No such file or directory
# ERROR: Failed to manage repository:
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\lyrastartergame'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/samples/lyrastartergame.git 'source\_repos-available\lyrastartergame--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\lyrastartergame--dev': No such file or directory'
#
#
# ERROR: Failed to manage repository:
#
#
# [repo_manager] Error during clone and checkout process for 'source\content\unitychessgame'
# - Error: Command failed: 'git clone --filter=blob:none --no-checkout --branch dev -q https://gitlab.acceleratxr.com/Core/samples/unitychessgame.git 'source\_repos-available\unitychessgame--dev''
# Error: 'fatal: could not create leading directories of 'source\_repos-available\unitychessgame--dev': No such file or directory'
#
#
#
# Exception occurred:
#   File "d:\workspaces\multi_repo_docs\docs_update\venv\lib\site-packages\sphinx\jinja2glue.py", line 206, in newest_template_mtime
# ValueError: max() arg is an empty sequence
# Traceback (most recent call last):
#   File "d:\workspaces\multi_repo_docs\docs_update\venv\lib\site-packages\sphinx\cmd\build.py", line 337, in build_main
#   File "d:\workspaces\multi_repo_docs\docs_update\venv\lib\site-packages\sphinx\application.py", line 351, in build
#   File "d:\workspaces\multi_repo_docs\docs_update\venv\lib\site-packages\sphinx\builders\__init__.py", line 292, in build_update
#   File "d:\workspaces\multi_repo_docs\docs_update\venv\lib\site-packages\sphinx\builders\html\__init__.py", line 400, in get_outdated_docs
#   File "d:\workspaces\multi_repo_docs\docs_update\venv\lib\site-packages\sphinx\jinja2glue.py", line 206, in newest_template_mtime
# ValueError: max() arg is an empty sequence
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\thoma\miniconda3\envs\py310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\thoma\miniconda3\envs\py310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "d:\workspaces\multi_repo_docs\docs_update\venv\Scripts\sphinx-build.exe\__main__.py", line 7, in <module>
#   File "d:\workspaces\multi_repo_docs\docs_update\venv\lib\site-packages\sphinx\cmd\build.py", line 382, in main
#   File "d:\workspaces\multi_repo_docs\docs_update\venv\lib\site-packages\sphinx\cmd\build.py", line 217, in make_main
#   File "d:\workspaces\multi_repo_docs\docs_update\venv\lib\site-packages\sphinx\cmd\make_mode.py", line 176, in run_make_mode
#   File "d:\workspaces\multi_repo_docs\docs_update\venv\lib\site-packages\sphinx\cmd\make_mode.py", line 164, in run_generic_build
#   File "d:\workspaces\multi_repo_docs\docs_update\venv\lib\site-packages\sphinx\cmd\build.py", line 340, in build_main
#   File "d:\workspaces\multi_repo_docs\docs_update\venv\lib\site-packages\sphinx\cmd\build.py", line 86, in handle_exception
#   File "d:\workspaces\multi_repo_docs\docs_update\venv\lib\site-packages\sphinx\util\exceptions.py", line 40, in save_traceback
#   File "c:\Users\thoma\miniconda3\envs\py310\lib\tempfile.py", line 483, in func_wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\thoma\miniconda3\envs\py310\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f503' in position 261: character maps to <undefined>
# The system cannot find the path specified.

# %% [markdown]
# ## Doc preview and debugging

# %% [markdown]
# ### Install preview/dev requirements

# %% [markdown]
# After running this next install, you'll want to make sure you have the recommended workspace extensions installed and reload the vscode window to make sure the esbonio plugin is loadded.
#
# `CTRL+SHIFT+P -> "Reload Window"`

# %%
# import requirements
# %pip install -r requirements-dev.txt
# Out:
# Requirement already satisfied: esbonio in .\venv\lib\site-packages (from -r requirements-dev.txt (line 6)) (0.16.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: lsp_devtools in .\venv\lib\site-packages (from -r requirements-dev.txt (line 7)) (0.2.3)
# Collecting rstcheck (from -r requirements-dev.txt (line 8))
#   Using cached rstcheck-6.2.1-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: sphinx in .\venv\lib\site-packages (from esbonio->-r requirements-dev.txt (line 6)) (7.3.7)
# Requirement already satisfied: platformdirs in .\venv\lib\site-packages (from esbonio->-r requirements-dev.txt (line 6)) (4.2.2)
# Requirement already satisfied: pygls>=1.1.0 in .\venv\lib\site-packages (from esbonio->-r requirements-dev.txt (line 6)) (1.3.1)
# Requirement already satisfied: pyspellchecker in .\venv\lib\site-packages (from esbonio->-r requirements-dev.txt (line 6)) (0.8.1)
# Requirement already satisfied: aiosqlite in .\venv\lib\site-packages (from lsp_devtools->-r requirements-dev.txt (line 7)) (0.20.0)
# Requirement already satisfied: stamina in .\venv\lib\site-packages (from lsp_devtools->-r requirements-dev.txt (line 7)) (24.2.0)
# Requirement already satisfied: textual>=0.41.0 in .\venv\lib\site-packages (from lsp_devtools->-r requirements-dev.txt (line 7)) (0.69.0)
# Collecting rstcheck-core>=1.1 (from rstcheck->-r requirements-dev.txt (line 8))
#   Using cached rstcheck_core-1.2.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting typer>=0.4.1 (from typer[all]>=0.4.1->rstcheck->-r requirements-dev.txt (line 8))
#   Using cached typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: cattrs>=23.1.2 in .\venv\lib\site-packages (from pygls>=1.1.0->esbonio->-r requirements-dev.txt (line 6)) (23.2.3)
# Requirement already satisfied: lsprotocol==2023.0.1 in .\venv\lib\site-packages (from pygls>=1.1.0->esbonio->-r requirements-dev.txt (line 6)) (2023.0.1)
# Requirement already satisfied: attrs>=21.3.0 in .\venv\lib\site-packages (from lsprotocol==2023.0.1->pygls>=1.1.0->esbonio->-r requirements-dev.txt (line 6)) (23.2.0)
# Requirement already satisfied: docutils>=0.7 in .\venv\lib\site-packages (from rstcheck-core>=1.1->rstcheck->-r requirements-dev.txt (line 8)) (0.20.1)
# Collecting pydantic>=2 (from rstcheck-core>=1.1->rstcheck->-r requirements-dev.txt (line 8))
#   Downloading pydantic-2.7.4-py3-none-any.whl.metadata (109 kB)
#      ---------------------------------------- 0.0/109.4 kB ? eta -:--:--
#      --------------------- ----------------- 61.4/109.4 kB 3.4 MB/s eta 0:00:01
#      -------------------------------------- 109.4/109.4 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: markdown-it-py>=2.1.0 in .\venv\lib\site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->lsp_devtools->-r requirements-dev.txt (line 7)) (3.0.0)
# Requirement already satisfied: rich>=13.3.3 in .\venv\lib\site-packages (from textual>=0.41.0->lsp_devtools->-r requirements-dev.txt (line 7)) (13.7.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.4.0 in .\venv\lib\site-packages (from textual>=0.41.0->lsp_devtools->-r requirements-dev.txt (line 7)) (4.12.2)
# Collecting click>=8.0.0 (from typer>=0.4.1->typer[all]>=0.4.1->rstcheck->-r requirements-dev.txt (line 8))
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.4.1->typer[all]>=0.4.1->rstcheck->-r requirements-dev.txt (line 8))
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: sphinxcontrib-applehelp in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (1.0.8)
# Requirement already satisfied: sphinxcontrib-devhelp in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (1.0.6)
# Requirement already satisfied: sphinxcontrib-jsmath in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (2.0.5)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (1.0.7)
# Requirement already satisfied: Jinja2>=3.0 in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (3.1.4)
# Requirement already satisfied: Pygments>=2.14 in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (2.18.0)
# Requirement already satisfied: snowballstemmer>=2.0 in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (2.2.0)
# Requirement already satisfied: babel>=2.9 in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (2.15.0)
# Requirement already satisfied: alabaster~=0.7.14 in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (1.4.1)
# Requirement already satisfied: requests>=2.25.0 in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (2.32.3)
# Requirement already satisfied: packaging>=21.0 in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (24.1)
# Requirement already satisfied: tomli>=2 in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (2.0.1)
# Requirement already satisfied: colorama>=0.4.5 in .\venv\lib\site-packages (from sphinx->esbonio->-r requirements-dev.txt (line 6)) (0.4.6)
# Requirement already satisfied: tenacity in .\venv\lib\site-packages (from stamina->lsp_devtools->-r requirements-dev.txt (line 7)) (8.3.0)
# Requirement already satisfied: exceptiongroup>=1.1.1 in .\venv\lib\site-packages (from cattrs>=23.1.2->pygls>=1.1.0->esbonio->-r requirements-dev.txt (line 6)) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in .\venv\lib\site-packages (from Jinja2>=3.0->sphinx->esbonio->-r requirements-dev.txt (line 6)) (2.1.5)
# Requirement already satisfied: mdurl~=0.1 in .\venv\lib\site-packages (from markdown-it-py>=2.1.0->markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->lsp_devtools->-r requirements-dev.txt (line 7)) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in .\venv\lib\site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->lsp_devtools->-r requirements-dev.txt (line 7)) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in .\venv\lib\site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->lsp_devtools->-r requirements-dev.txt (line 7)) (0.4.1)
# Collecting annotated-types>=0.4.0 (from pydantic>=2->rstcheck-core>=1.1->rstcheck->-r requirements-dev.txt (line 8))
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.18.4 (from pydantic>=2->rstcheck-core>=1.1->rstcheck->-r requirements-dev.txt (line 8))
#   Downloading pydantic_core-2.18.4-cp310-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\venv\lib\site-packages (from requests>=2.25.0->sphinx->esbonio->-r requirements-dev.txt (line 6)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in .\venv\lib\site-packages (from requests>=2.25.0->sphinx->esbonio->-r requirements-dev.txt (line 6)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\venv\lib\site-packages (from requests>=2.25.0->sphinx->esbonio->-r requirements-dev.txt (line 6)) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in .\venv\lib\site-packages (from requests>=2.25.0->sphinx->esbonio->-r requirements-dev.txt (line 6)) (2024.6.2)
# Requirement already satisfied: uc-micro-py in .\venv\lib\site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->lsp_devtools->-r requirements-dev.txt (line 7)) (1.0.3)
# Using cached rstcheck-6.2.1-py3-none-any.whl (8.5 kB)
# Using cached rstcheck_core-1.2.1-py3-none-any.whl (27 kB)
# Using cached typer-0.12.3-py3-none-any.whl (47 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading pydantic-2.7.4-py3-none-any.whl (409 kB)
#    ---------------------------------------- 0.0/409.0 kB ? eta -:--:--
#    ------------ --------------------------- 122.9/409.0 kB 7.0 MB/s eta 0:00:01
#    ------------ --------------------------- 122.9/409.0 kB 7.0 MB/s eta 0:00:01
#    ------------------- -------------------- 194.6/409.0 kB 1.7 MB/s eta 0:00:01
#    ------------------- -------------------- 194.6/409.0 kB 1.7 MB/s eta 0:00:01
#    ------------------- -------------------- 194.6/409.0 kB 1.7 MB/s eta 0:00:01
#    --------------------- ---------------- 235.5/409.0 kB 962.7 kB/s eta 0:00:01
#    ---------------------------------- ----- 348.2/409.0 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  399.4/409.0 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 409.0/409.0 kB 1.1 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.4-cp310-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    - -------------------------------------- 0.1/1.9 MB 1.9 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.2/1.9 MB 2.4 MB/s eta 0:00:01
#    ------ --------------------------------- 0.3/1.9 MB 2.1 MB/s eta 0:00:01
#    -------- ------------------------------- 0.4/1.9 MB 2.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.6/1.9 MB 2.5 MB/s eta 0:00:01
#    -------------- ------------------------- 0.7/1.9 MB 2.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.8/1.9 MB 2.5 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/1.9 MB 2.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.1/1.9 MB 2.7 MB/s eta 0:00:01
#    ------------------------- -------------- 1.2/1.9 MB 2.7 MB/s eta 0:00:01
#    --------------------------- ------------ 1.3/1.9 MB 2.7 MB/s eta 0:00:01
#    ------------------------------- -------- 1.5/1.9 MB 2.7 MB/s eta 0:00:01
#    ------------------------------- -------- 1.5/1.9 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.9 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.9 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.9 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.9 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.9 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 2.2 MB/s eta 0:00:00
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Installing collected packages: shellingham, pydantic-core, click, annotated-types, pydantic, typer, rstcheck-core, rstcheck
# Successfully installed annotated-types-0.7.0 click-8.1.7 pydantic-2.7.4 pydantic-core-2.18.4 rstcheck-6.2.1 rstcheck-core-1.2.1 shellingham-1.5.4 typer-0.12.3
# WARNING: typer 0.12.3 does not provide the extra 'all'
